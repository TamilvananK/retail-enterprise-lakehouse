# %%
snowflakeOptions = {
  "sfUrl": "WWKLJLK-SK03539.snowflakecomputing.com",
  "sfUser": "tamilvanan",
  "sfPassword": "4hh44jFxBf5VQ6e",
  "sfDatabase": "retail_enterprise_db",
  "sfWarehouse": "retail_loading_wh",
  "sfRole": "retail_loader_role"
}
